# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('../data/steam.csv')
#Drop unused values
data.drop(data.columns.difference(['positive_ratings','average_playtime']), 1, inplace=True)
data
# Out:
#        positive_ratings  average_playtime
# 0                124534             17612
# 1                  3318               277
# 2                  3416               187
# 3                  1273               258
# 4                  5250               624
# 5                  2758               175
# 6                 27755              1300
# 7                 12120               427
# 8                  3822               361
# 9                 67902               691
# 10                76640              6842
# 11                 3767               190
# 12                10489              1356
# 13                 6020               311
# 14                 5783                46
# 15                 1362               102
# 16                 7908               281
# 17                51801               288
# 18                13902               354
# 19               515879              8495
# 20                17951               897
# 21               251789              1615
# 22               863507             23944
# 23               138220              1102
# 24                17435               371
# 25              2644404             22494
# 26                   40                 0
# 27                 1562               232
# 28                53710              1328
# 29                  468                 0
# ...                 ...               ...
# 27045                13                 0
# 27046                 3                 0
# 27047                25                 0
# 27048                 4                 0
# 27049                 2                 0
# 27050                 2                 0
# 27051                 0                 0
# 27052                 3                 0
# 27053                 7                 0
# 27054                 3                 0
# 27055                 1                 0
# 27056                 0                 0
# 27057                 4                 0
# 27058                 7                 0
# 27059                 1                 0
# 27060                 0                 0
# 27061                13                 0
# 27062                 4                 0
# 27063                 2                 0
# 27064                 6                 0
# 27065                 9                 0
# 27066                 3                 0
# 27067                13                 0
# 27068                 4                 0
# 27069                 2                 0
# 27070                 3                 0
# 27071                 8                 0
# 27072                 0                 0
# 27073                 2                 0
# 27074                 4                 0
#
# [27075 rows x 2 columns]

# %%
data.describe()
# Out:
#        positive_ratings  average_playtime
# count      2.707500e+04      27075.000000
# mean       1.000559e+03        149.804949
# std        1.898872e+04       1827.038141
# min        0.000000e+00          0.000000
# 25%        6.000000e+00          0.000000
# 50%        2.400000e+01          0.000000
# 75%        1.260000e+02          0.000000
# max        2.644404e+06     190625.000000

# %%
#Remove outliers
#data = data.drop(data[data.average_playtime > 5000].index)
P = np.percentile(data.average_playtime, [5, 95])
data = df[(df.average_playtime > P[0]) & (df.average_playtime < P[1])]
data.describe()
# Out:
#        positive_ratings  average_playtime
# count      26969.000000      26969.000000
# mean         700.688643         83.583670
# std         5513.842516        325.026803
# min            0.000000          0.000000
# 25%            6.000000          0.000000
# 50%           24.000000          0.000000
# 75%          123.000000          0.000000
# max       308657.000000       4975.000000

# %%
X = DataFrame(data, columns=['positive_ratings'])
y = DataFrame(data, columns=['average_playtime'])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.title('Positive Rating vs Average Playtime')
plt.xlabel('rating')
plt.ylabel('playtime')
plt.ylim(0, 6000)
plt.xlim(0, 15000)
plt.show()

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Slope Coeffiicient
regression.coef_
# Out:
# array([[0.02598894]])

# %%
# Intercept
regression.intercept_
# Out:
# array([65.37351824])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, regression.predict(X), color='red', linewidth=2)
plt.title('Positive Rating vs Average Playtime')
plt.xlabel('rating')
plt.ylabel('playtime')
plt.ylim(0, 12000)
plt.xlim(0, 25000)
plt.show()

# %%
regression.score(X, y)
# Out:
# 0.194378105527391
